# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyaBansal68/ML-Project-winter-2022/blob/main/Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Football/train.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df
# Out:
#               id target      home_team_name         away_team_name  \
# 0       11906497   away   Newell's Old Boys            River Plate
# 1       11984383   home         Real Estelí  Deportivo Las Sabanas
# 2       11983301   draw               UPNFM               Marathón
# 3       11983471   away                León                Morelia
# 4       11883005   home      Cobán Imperial                 Iztapa
# ...          ...    ...                 ...                    ...
# 110933  18030016   draw  Zamora Fútbol Club    Hermanos Colmenares
# 110934  18030096   away          Royal Pari      Oriente Petrolero
# 110935  17715497   draw        São Bernardo             Água Santa
# 110936  17944153   away             Everton              La Serena
# 110937  17786297   home               Colón     Arsenal de Sarandi
#
#               match_date          league_name  league_id is_cup  \
# 0       01-12-2019 00:45            Superliga        636  False
# ...

# %%
df.describe()
# Out:
#                  id      league_id  home_team_coach_id  away_team_coach_id  \
# count  1.109380e+05  110938.000000        8.921700e+04        8.912300e+04
# mean   1.519875e+07     910.457012        1.287134e+07        1.291552e+07
# std    2.536393e+06     549.120985        1.578479e+07        1.580344e+07
# min    1.142829e+07       2.000000        2.000000e+00        2.000000e+00
# 25%    1.200038e+07     444.000000        4.596120e+05        4.595650e+05
# 50%    1.675988e+07     947.000000        1.552728e+06        1.552806e+06
# 75%    1.724230e+07    1293.000000        3.243116e+07        3.279539e+07
# max    1.805384e+07    2039.000000        3.756849e+07        3.756847e+07
#
#        home_team_history_is_play_home_1  home_team_history_is_play_home_2  \
# count                     109779.000000                     108487.000000
# mean                           0.306944                          0.567801
# ...

# %%
count_missing = pd.DataFrame([df.isna().mean()]).T
count_missing = count_missing.rename(columns={0: "train_missing", 1: "test_missing"})

count_missing.query("train_missing > 0.1 and train_missing < 0.2").plot(kind="barh", figsize=(15, 30), title="% of Values Missing")

# %%
count_missing.query("train_missing > 0.2 and train_missing < 0.3").plot(kind="barh", figsize=(15, 30), title="% of Values Missing")

# %%
sns.set_theme(style="darkgrid")
sns.countplot(x="target",data=df)

# %%
df["home_team_name"].value_counts()
# Out:
# Al Ittihad          91
# River Plate         71
# Rangers             64
# Liverpool           63
# Al Ahli             62
#                     ..
# Atlético GO U20      1
# Cray Valley (PM)     1
# Worcester City       1
# Velke Lovce          1
# EB / Streymur II     1
# Name: home_team_name, Length: 9813, dtype: int64

# %%
df["away_team_name"].value_counts()
# Out:
# Al Ittihad              82
# River Plate             77
# Liverpool               65
# Rangers                 64
# Al Ahli                 64
#                         ..
# Hlinsko                  1
# Tatran Rakovnik          1
# Makedonikos Foufas       1
# Hohenstein-Ernstthal     1
# Úlfarnir                 1
# Name: away_team_name, Length: 9892, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(x="home_team_name",hue="target",data=df,order=df.home_team_name.value_counts().iloc[:5].index)

# %%
plt.figure(figsize=(10,10))
sns.countplot(x="away_team_name",hue="target",data=df,order=df.away_team_name.value_counts().iloc[:5].index)

# %%
sns.countplot(df["is_cup"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df["home_team_coach_id"].value_counts()
# Out:
# 37252510.0    4455
# 2511092.0       49
# 524307.0        48
# 7862.0          46
# 455357.0        46
#               ...
# 37524413.0       1
# 1552968.0        1
# 20336125.0       1
# 37455116.0       1
# 86159.0          1
# Name: home_team_coach_id, Length: 8804, dtype: int64

# %%
df["away_team_coach_id"].value_counts()
# Out:
# 37252510.0    4512
# 455361.0        49
# 524307.0        47
# 466541.0        47
# 2511092.0       45
#               ...
# 525060.0         1
# 534241.0         1
# 37553957.0       1
# 37553867.0       1
# 37567817.0       1
# Name: away_team_coach_id, Length: 8938, dtype: int64

# %%
df.head(5)
# Out:
#          id target     home_team_name         away_team_name  \
# 0  11906497   away  Newell's Old Boys            River Plate
# 1  11984383   home        Real Estelí  Deportivo Las Sabanas
# 2  11983301   draw              UPNFM               Marathón
# 3  11983471   away               León                Morelia
# 4  11883005   home     Cobán Imperial                 Iztapa
#
#          match_date       league_name  league_id is_cup  home_team_coach_id  \
# 0  01-12-2019 00:45         Superliga        636  False            468196.0
# 1  01-12-2019 01:00  Primera Division        752  False            516788.0
# 2  01-12-2019 01:00     Liga Nacional        734  False           2510608.0
# 3  01-12-2019 01:00           Liga MX        743  False           1552508.0
# 4  01-12-2019 01:00     Liga Nacional        705  False            429958.0
#
#    away_team_coach_id  ... away_team_history_league_id_1  \
# 0            468200.0  ...                        1122.0
# ...

# %%
corr = df.corr()
sns.heatmap(corr, cmap="Blues", annot=True)
